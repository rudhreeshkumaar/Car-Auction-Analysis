# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
import plotly.graph_objects as go




from collections import defaultdict
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df = pd.read_csv("D:/DM_Project_Dataset/training_cleaned.csv")
df.head()
# Out:
#    RefId  IsBadBuy   PurchDate  Auction  VehicleAge      Make  \
# 0    326         1  2010-10-25    ADESA           2       KIA
# 1  42991         0  2009-05-27  MANHEIM           3     DODGE
# 2  55273         0  2010-03-18    OTHER           2     DODGE
# 3  29058         0  2009-06-08    OTHER           4      FORD
# 4  34991         0  2009-03-04  MANHEIM           4  CHRYSLER
#
#                   Model SubModel   Color Transmission  ...  \
# 0               SPECTRA   MEDIUM    BLUE         AUTO  ...
# 1  STRATUS V6 2.7L V6 M   MEDIUM  SILVER         AUTO  ...
# 2               CALIBER   MEDIUM   BLACK         AUTO  ...
# 3  FREESTAR FWD V6 3.9L      VAN   BROWN         AUTO  ...
# 4  TOWN & COUNTRY FWD V      VAN    BLUE         AUTO  ...
#
#    TopThreeAmericanName  BYRNO VehBCost IsOnlineSale WarrantyCost  Region  \
# 0                 OTHER   5546   6100.0            0          533     SAT
# 1              CHRYSLER  99750   4000.0            0         1630     SAT
# 2              CHRYSLER  99761   7500.0            0          693     WSC
# 3                  FORD  99761   4725.0            0         1633     MNT
# 4              CHRYSLER  20833   5670.0            0         1623     WSC
#
#    IsBase  AuctionAVG  RetailAVG     Trend
# 0      NO      7128.5    10300.0 -0.012594
# 1      NO      5970.5     6948.0  0.000000
# 2      NO      8061.5    11199.0 -0.022092
# 3      NO      5737.5     6696.5  0.000000
# 4     YES      6061.0     7046.0  0.004692
#
# [5 rows x 24 columns]

# %%
df_clus = df.drop(columns=['RefId',
        'PurchDate',
        'IsBadBuy',
        'Auction',
        'Make',
        'Model',
        'WheelTypeID',
        'Nationality',
        'Size',
        'Color',
        'Transmission',
        'BYRNO',
        'TopThreeAmericanName',
        'SubModel',
        'VehicleAge',
        'IsOnlineSale',
        'Region',
        'IsBase',])
df_clus.dropna(inplace=True)
len(df_clus)
df_clus.head()
# Out:
#    VehOdo  VehBCost  WarrantyCost  AuctionAVG  RetailAVG     Trend
# 0   61184    6100.0           533      7128.5    10300.0 -0.012594
# 1   92383    4000.0          1630      5970.5     6948.0  0.000000
# 2   45965    7500.0           693      8061.5    11199.0 -0.022092
# 3   80169    4725.0          1633      5737.5     6696.5  0.000000
# 4   77372    5670.0          1623      6061.0     7046.0  0.004692

# %% [markdown]
# # K-Means with Z-Score

# %%
scaler = StandardScaler()
z_df_clus = scaler.fit_transform(df_clus.values)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters=5, n_init=50, max_iter=500)
kmeans.fit(z_df_clus)
# Out:
# KMeans(max_iter=500, n_clusters=5, n_init=50)

# %%
plt.scatter(df_clus['AuctionAVG'], df_clus['WarrantyCost'], 
            c=kmeans.labels_, s=60)

# %% [markdown]
# # K-Means with MinMax

# %%
scaler = MinMaxScaler()
minmax_df_clus = scaler.fit_transform(df_clus.values)

# %%
kmeans_2 = KMeans(n_clusters=5, n_init=50, max_iter=500)
kmeans_2.fit(minmax_df_clus)
# Out:
# KMeans(max_iter=500, n_clusters=5, n_init=50)

# %%
plt.scatter(df_clus['WarrantyCost'], df_clus['VehBCost'], 
            c=kmeans_2.labels_, s=60)
